# %%
# %matplotlib inline

# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# Load data
raw_data = pd.read_csv('adult.csv')
print raw_data.shape
raw_data.head()
# Out:
# (32561, 15)
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
# Remove observations with missing values
filtered_data = raw_data[~raw_data.eq('?').any(1)]
filtered_data = filtered_data.drop(['fnlwgt','education.num'],1)
print filtered_data.shape
print filtered_data.income.value_counts()
filtered_data.head()
# Out:
# (30162, 13)
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64
#    age workclass     education marital.status         occupation  \
# 1   82   Private       HS-grad        Widowed    Exec-managerial
# 3   54   Private       7th-8th       Divorced  Machine-op-inspct
# 4   41   Private  Some-college      Separated     Prof-specialty
# 5   34   Private       HS-grad       Divorced      Other-service
# 6   38   Private          10th      Separated       Adm-clerical
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 1  Not-in-family  White  Female             0          4356              18
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
# 5      Unmarried  White  Female             0          3770              45
# 6      Unmarried  White    Male             0          3770              40
#
#   native.country income
# 1  United-States  <=50K
# 3  United-States  <=50K
# 4  United-States  <=50K
# 5  United-States  <=50K
# 6  United-States  <=50K

# %%
# Convert categorical data to numbers using one-hot encoding
filtered_data['income'] = filtered_data['income'].replace({'<=50K': 0, '>50K': 1})
encoded_data = pd.get_dummies(filtered_data)
encoded_data.head()
# Out:
#    age  capital.gain  capital.loss  hours.per.week  income  \
# 1   82             0          4356              18       0
# 3   54             0          3900              40       0
# 4   41             0          3900              40       0
# 5   34             0          3770              45       0
# 6   38             0          3770              40       0
#
#    workclass_Federal-gov  workclass_Local-gov  workclass_Private  \
# 1                      0                    0                  1
# 3                      0                    0                  1
# 4                      0                    0                  1
# 5                      0                    0                  1
# 6                      0                    0                  1
#
#    workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# 1                       0                           0
# 3                       0                           0
# 4                       0                           0
# 5                       0                           0
# 6                       0                           0
#
#              ...              native.country_Portugal  \
# 1            ...                                    0
# 3            ...                                    0
# 4            ...                                    0
# 5            ...                                    0
# 6            ...                                    0
#
#    native.country_Puerto-Rico  native.country_Scotland  native.country_South  \
# 1                           0                        0                     0
# 3                           0                        0                     0
# 4                           0                        0                     0
# 5                           0                        0                     0
# 6                           0                        0                     0
#
#    native.country_Taiwan  native.country_Thailand  \
# 1                      0                        0
# 3                      0                        0
# 4                      0                        0
# 5                      0                        0
# 6                      0                        0
#
#    native.country_Trinadad&Tobago  native.country_United-States  \
# 1                               0                             1
# 3                               0                             1
# 4                               0                             1
# 5                               0                             1
# 6                               0                             1
#
#    native.country_Vietnam  native.country_Yugoslavia
# 1                       0                          0
# 3                       0                          0
# 4                       0                          0
# 5                       0                          0
# 6                       0                          0
#
# [5 rows x 103 columns]

# %%
# Training and testing data
X = encoded_data.loc[:, encoded_data.columns != 'income']
Y = encoded_data['income']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 42)

# %% [markdown]
# ### Decision Tree

# %%
# Decision tree
clf = DecisionTreeClassifier()
clf.fit(X_train,Y_train)
Y_pred = clf.predict(X_test)
print classification_report(Y_test,Y_pred)
print accuracy_score(Y_test,Y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.88      0.88      0.88      5643
#           1       0.65      0.63      0.64      1898
#
# avg / total       0.82      0.82      0.82      7541
#
# 0.8207134332316669

# %% [markdown]
# ### Random Forest

# %%
clf = RandomForestClassifier()
clf.fit(X_train,Y_train)
Y_pred = clf.predict(X_test)
print classification_report(Y_test,Y_pred)
print accuracy_score(Y_test,Y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.92      0.90      5643
#           1       0.72      0.60      0.65      1898
#
# avg / total       0.83      0.84      0.83      7541
#
# 0.8395438270786368

# %%
# Tuning random forest model
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 600, num = 3)]
max_depth = [int(x) for x in np.linspace(5, 25, num = 3)]
max_depth.append(None)

param_grid = { 
    'n_estimators': n_estimators,
    'max_depth' : max_depth,
    'max_features': ['auto', 'sqrt', 'log2'],
}

grid_search = GridSearchCV(clf, param_grid=param_grid, verbose = 2, n_jobs= -1)
grid_search.fit(X_train,Y_train)
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:  5.1min finished
# {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 350}

# %%
# Retrain using tuned paramters
clf = RandomForestClassifier(criterion='gini',max_depth=15,max_features='sqrt',n_estimators=350)
clf.fit(X_train,Y_train)
Y_pred = clf.predict(X_test)
print classification_report(Y_test,Y_pred)
print accuracy_score(Y_test,Y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.95      0.91      5643
#           1       0.79      0.58      0.67      1898
#
# avg / total       0.85      0.86      0.85      7541
#
# 0.8559872695928922

# %% [markdown]
# Tuned random forest (85.6% accuracy) outperforms un-tuned random forest(83.7%), which outperforms un-tuned decision tree (81.9%)

# %% [markdown]
# ### Feature rankings

# %%
idx = np.argsort(clf.feature_importances_)[::-1]

print('Feature importance rankings:')
for f in range(X_train.shape[1]):
    print('%d. %s (%f)' % (f + 1, X_train.columns[indices[f]], clf.feature_importances_[indices[f]]))
# Out:
# Feature importance rankings:
# 1. capital.gain (0.156884)
# 2. marital.status_Married-civ-spouse (0.122876)
# 3. age (0.088665)
# 4. relationship_Husband (0.083567)
# 5. hours.per.week (0.060559)
# 6. capital.loss (0.044951)
# 7. marital.status_Never-married (0.043286)
# 8. education_Bachelors (0.033386)
# 9. occupation_Exec-managerial (0.033326)
# 10. occupation_Prof-specialty (0.031614)
# 11. relationship_Wife (0.019713)
# 12. education_Masters (0.019597)
# 13. relationship_Not-in-family (0.018735)
# 14. relationship_Own-child (0.017551)
# 15. sex_Male (0.016820)
# 16. sex_Female (0.015859)
# 17. education_HS-grad (0.015112)
# 18. education_Prof-school (0.013293)
# 19. occupation_Other-service (0.011671)
# 20. marital.status_Divorced (0.009831)
# 21. education_Doctorate (0.008107)
# 22. relationship_Unmarried (0.008071)
# 23. workclass_Self-emp-not-inc (0.008009)
# 24. workclass_Private (0.007692)
# 25. workclass_Self-emp-inc (0.006335)
# 26. education_Some-college (0.005698)
# 27. occupation_Farming-fishing (0.005528)
# 28. workclass_Federal-gov (0.005170)
# 29. native.country_United-States (0.004627)
# 30. race_White (0.004236)
# 31. occupation_Craft-repair (0.004168)
# 32. occupation_Sales (0.004114)
# 33. education_7th-8th (0.003838)
# 34. occupation_Handlers-cleaners (0.003660)
# 35. workclass_Local-gov (0.003543)
# 36. occupation_Machine-op-inspct (0.003245)
# 37. race_Black (0.003229)
# 38. occupation_Tech-support (0.003100)
# 39. education_11th (0.003042)
# 40. occupation_Adm-clerical (0.002903)
# 41. workclass_State-gov (0.002894)
# 42. education_10th (0.002806)
# 43. occupation_Transport-moving (0.002704)
# 44. native.country_Mexico (0.002416)
# 45. race_Asian-Pac-Islander (0.002306)
# 46. education_Assoc-voc (0.002112)
# 47. education_9th (0.002063)
# 48. education_Assoc-acdm (0.002026)
# 49. marital.status_Separated (0.001974)
# 50. marital.status_Widowed (0.001839)
# 51. occupation_Protective-serv (0.001825)
# 52. relationship_Other-relative (0.001761)
# 53. race_Amer-Indian-Eskimo (0.001189)
# 54. education_5th-6th (0.001171)
# 55. native.country_England (0.000982)
# 56. native.country_Philippines (0.000892)
# 57. native.country_India (0.000889)
# 58. native.country_Germany (0.000863)
# 59. marital.status_Married-spouse-absent (0.000789)
# 60. race_Other (0.000784)
# 61. education_12th (0.000707)
# 62. native.country_Canada (0.000694)
# 63. native.country_Italy (0.000624)
# 64. native.country_Japan (0.000585)
# 65. marital.status_Married-AF-spouse (0.000550)
# 66. native.country_China (0.000514)
# 67. native.country_South (0.000497)
# 68. native.country_Cuba (0.000476)
# 69. native.country_Iran (0.000345)
# 70. native.country_Puerto-Rico (0.000338)
# 71. native.country_Poland (0.000317)
# 72. education_1st-4th (0.000310)
# 73. native.country_Jamaica (0.000304)
# 74. native.country_France (0.000297)
# 75. native.country_Greece (0.000286)
# 76. native.country_Vietnam (0.000266)
# 77. native.country_Cambodia (0.000262)
# 78. native.country_Yugoslavia (0.000221)
# 79. native.country_Taiwan (0.000213)
# 80. native.country_El-Salvador (0.000206)
# 81. native.country_Hong (0.000193)
# 82. native.country_Dominican-Republic (0.000189)
# 83. native.country_Portugal (0.000178)
# 84. native.country_Hungary (0.000176)
# 85. native.country_Ireland (0.000159)
# 86. native.country_Guatemala (0.000138)
# 87. native.country_Haiti (0.000129)
# 88. occupation_Priv-house-serv (0.000126)
# 89. native.country_Trinadad&Tobago (0.000114)
# 90. native.country_Columbia (0.000104)
# 91. native.country_Ecuador (0.000097)
# 92. native.country_Thailand (0.000093)
# 93. education_Preschool (0.000085)
# 94. native.country_Nicaragua (0.000067)
# 95. native.country_Laos (0.000065)
# 96. native.country_Scotland (0.000055)
# 97. native.country_Peru (0.000048)
# 98. native.country_Outlying-US(Guam-USVI-etc) (0.000034)
# 99. workclass_Without-pay (0.000026)
# 100. occupation_Armed-Forces (0.000007)
# 101. native.country_Honduras (0.000005)
# 102. native.country_Holand-Netherlands (0.000003)
